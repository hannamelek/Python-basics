# %%
#day 6 hamming distance (diff btw two seq)

# %%
s1 = "GAGCCTACTAACGGGAT"
s2 = "CATCGTAATGACGGCCT"

# %%
distance = 0

# %%
for i in range(len(s1)):

    if s1[i] != s2[i]:
       distance = distance + 1

print(distance)
# Out:
# 7

# %%
# comparing each base of the 2 sequences and each they differ +1 is added to the distance hence "7" is the output executed

# %%
s1 = "GAGGTACTAACATGGAT"
s2 = "CATCGTAATGACGGCCT"

# %%
distance = 0

# %%
for i in range(len(s1)):

    if s1[i] != s2[i]:
        distance = distance + 1

print(distance)
# Out:
# 14

# %%
k = 2
m = 2
n = 2

total = k + m + n

recessive = (
    (n/total) * ((n-1)/(total-1)) +
    (n/total) * (m/(total-1)) * 0.5 +
    (m/total) * (n/(total-1)) * 0.5 +
    (m/total) * ((m-1)/(total-1)) * 0.25
)

dominant = 1 - recessive

print(dominant)
# Out:
# 0.7833333333333333
